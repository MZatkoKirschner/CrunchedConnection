# %%
#Import modules
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
#Read dataset
file = '../data/cleaned/merged/df_cleaned.csv'
df = pd.read_csv(file)
df
# Out:
#          Unnamed: 0  OP_UNIQUE_CARRIER  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  \
# 0             10607                 11              10800            12889
# 1             10724                 11              13796            14570
# 2             10802                  4              14771            14487
# 3             10884                 11              10800            14771
# 4             10897                 11              13796            10800
# ...             ...                ...                ...              ...
# 2781964     7422006                  6              11618            14869
# 2781965     7422008                 12              12478            14771
# 2781966     7422009                  4              12892            14698
# 2781967     7422032                  4              14771            13891
# 2781968     7422034                  2              14100            12892
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'OP_UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID',
#        'DEST_AIRPORT_ID', 'ARR_DELAY_GROUP', 'DISTANCE_GROUP', 'tmpF_D',
#        'dptF_D', 'CC_D', 'dir_D', 'spd_D', '6hPrecPrb_D', '6hQntPrec_D',
#        'ceil_D', 'visib_D', 'obstruc_D', 'fzRnPrb_D', 'snowPrb_D', 'precTyp_D',
#        '6hrTsPrb_15mi_D', '6hrSvrTsPrb_25mi_D', 'tmpF_A', 'dptF_A', 'CC_A',
#        'dir_A', 'spd_A', '6hPrecPrb_A', '6hQntPrec_A', 'ceil_A', 'visib_A',
#        'obstruc_A', 'fzRnPrb_A', 'snowPrb_A', 'precTyp_A', '6hrTsPrb_15mi_A',
#        '6hrSvrTsPrb_25mi_A'],
#       dtype='object')

# %% [markdown]
# ### Histogram

# %%
df['ARR_DELAY_GROUP'].hist()

# %%
df['ARR_DELAY_GROUP'].value_counts()
# Out:
# -1.0     1106911
# -2.0      681472
#  0.0      472238
#  1.0      183560
#  2.0       95575
#  3.0       58843
#  4.0       40570
#  12.0      34790
#  5.0       29223
#  6.0       21991
#  7.0       17140
#  8.0       13553
#  9.0       10641
#  10.0       8608
#  11.0       6854
# Name: ARR_DELAY_GROUP, dtype: int64

# %%
df['snowPrb_D'].hist()

# %%
df['6hPrecPrb_D'].hist()

# %%
df['6hrTsPrb_15mi_D'].hist()

# %%
df['6hrSvrTsPrb_25mi_D'].hist()

# %%
df['visib_D'].hist()

# %%
df['fzRnPrb_A'].hist()

# %%
# plotting a scatter matrix
#from matplotlib import cm

#X = df[['ARR_DELAY_GROUP', '6hPrecPrb_A', 'DISTANCE_GROUP', 'tmpF_D',
#       '6hPrecPrb_D','OP_UNIQUE_CARRIER','snowPrb_D','6hrSvrTsPrb_25mi_A']]
#y = df['ARR_DELAY_GROUP']

#cmap = cm.get_cmap('gnuplot')
#scatter = pd.plotting.scatter_matrix(X, c= y, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(9,9), cmap=cmap)

# %%
#Scatterplots

ax = sns.scatterplot(x=df['6hPrecPrb_D'],y=df['ARR_DELAY_GROUP'])

# %%
ax = sns.scatterplot(x=df['snowPrb_D'],y=df['ARR_DELAY_GROUP'])

# %%
ax = sns.scatterplot(x=df['6hrSvrTsPrb_25mi_A'],y=df['6hPrecPrb_D'])

# %%
plt.scatter(df['6hrSvrTsPrb_25mi_A'], df['6hPrecPrb_D'])
